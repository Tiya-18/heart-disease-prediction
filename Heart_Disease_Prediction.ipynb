# %%
import pandas as pd

df = pd.read_csv("/content/heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.shape
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# STEP 1: HANDLE MISSING VALUES
print("Missing values before processing:\n", df.isnull().sum())

for col in df.columns:
    if df[col].isnull().sum() > 0:
        if df[col].dtype in ['int64', 'float64']:
            df[col].fillna(df[col].median(), inplace=True)
        else:
            df[col].fillna(df[col].mode()[0], inplace=True)

print("Missing values after processing:\n", df.isnull().sum())
# Out:
# Missing values before processing:
#  age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64
# Missing values after processing:
#  age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# STEP 2: OUTLIER DETECTION (IQR METHOD)
def outlier_report(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return lower, upper

num_cols = ['age','trestbps','chol','thalach','oldpeak']
for col in num_cols:
    lower, upper = outlier_report(df[col])
    print(f"{col} → Outlier Range: below {lower}, above {upper}")
# Out:
# age → Outlier Range: below 28.5, above 80.5
# trestbps → Outlier Range: below 90.0, above 170.0
# chol → Outlier Range: below 115.0, above 371.0
# thalach → Outlier Range: below 81.0, above 217.0
# oldpeak → Outlier Range: below -2.7, above 4.5

# %%
# STEP 3: ENCODING
df_encoded = pd.get_dummies(df,
                            columns=['cp','restecg','slope','thal'],
                            drop_first=True)

# %%
# STEP 4: FEATURE/TARGET SEPARATION
X = df_encoded.drop("target", axis=1)
y = df_encoded["target"]

# %%
# STEP 5: SCALING
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print("Shape after scaling:", X_scaled.shape)
# Out:
# Shape after scaling: (1025, 19)

# %%
# STEP 6: TRAIN/VAL/TEST SPLIT
# --------------------------------------------------------
from sklearn.model_selection import train_test_split

X_train_val, X_test, y_train_val, y_test = train_test_split(
    X_scaled, y, test_size=0.15, random_state=42, stratify=y)

X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.17647, random_state=42, stratify=y_train_val)

print("Train set:", X_train.shape)
print("Validation set:", X_val.shape)
print("Test set:", X_test.shape)

print("\nData preprocessing completed successfully!")
# Out:
# Train set: (717, 19)
# Validation set: (154, 19)
# Test set: (154, 19)
#
# Data preprocessing completed successfully!

# %%
# View dataset shape and first few rows
print("Dataset Shape:", df.shape)
display(df.head())

# Statistical summary
print("\nSummary Statistics:")
display(df.describe())

# Information about data types
print("\nDataset Info:")
df.info()

# Check class balance
print("\nTarget Class Distribution:")
print(df['target'].value_counts())
# Out:
# Dataset Shape: (1025, 14)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
# Summary Statistics:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB
#
# Target Class Distribution:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Enable inline plotting
# %matplotlib inline

# Set general style
sns.set(style="whitegrid")

# ========== NUMERIC COLUMNS ==========
numeric_cols = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# HISTOGRAMS
plt.figure(figsize=(15, 8))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(2, 3, i)
    plt.hist(df[col])
    plt.title(f"Histogram of {col}")
plt.tight_layout()
plt.show()

# BOX PLOTS
plt.figure(figsize=(15, 8))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
plt.tight_layout()
plt.show()

# %%
categorical_cols = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']

plt.figure(figsize=(15, 12))
for i, col in enumerate(categorical_cols, 1):
    plt.subplot(3, 3, i)
    sns.countplot(data=df, x=col)
    plt.title(f"Countplot of {col}")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 10))
corr = df.corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
selected_cols = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target']
sns.pairplot(df[selected_cols], hue='target')
plt.show()

# %%
plt.figure(figsize=(15, 12))
for i, col in enumerate(['age', 'chol', 'trestbps', 'thalach', 'oldpeak'], 1):
    plt.subplot(3, 2, i)
    sns.kdeplot(data=df, x=col, hue='target', fill=True)
    plt.title(f"{col} Distribution by Target")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 12))
for i, col in enumerate(['sex', 'cp', 'exang', 'slope', 'ca', 'thal'], 1):
    plt.subplot(3, 2, i)
    sns.countplot(data=df, x=col, hue='target')
    plt.title(f"{col} vs Target")
plt.tight_layout()
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# --------------------------------------------
# MODEL DEFINITION
# --------------------------------------------
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),  # Input + Hidden Layer 1
    Dropout(0.2),                                                   # Regularization
    Dense(32, activation='relu'),                                   # Hidden Layer 2
    Dense(1, activation='sigmoid')                                  # Output Layer
])

# Model summary for your report
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         1,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,393 (13.25 KB)
#  Trainable params: 3,393 (13.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5694 - loss: 0.6973 - val_accuracy: 0.7532 - val_loss: 0.5274
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7689 - loss: 0.4975 - val_accuracy: 0.8117 - val_loss: 0.4334
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8317 - loss: 0.3848 - val_accuracy: 0.8182 - val_loss: 0.3957
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8558 - loss: 0.3571 - val_accuracy: 0.8247 - val_loss: 0.3750
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8463 - loss: 0.3735 - val_accuracy: 0.8182 - val_loss: 0.3622
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8665 - loss: 0.3158 - val_accuracy: 0.8377 - val_loss: 0.3514
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8671 - loss: 0.3126 - val_accuracy: 0.8312 - val_loss: 0.3410
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8629 - loss: 0.3007 - val_accuracy: 0.8571 - val_loss: 0.3289
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8763 - loss: 0.3107 - val_accuracy: 0.8571 - val_loss: 0.3159
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8701 - loss: 0.2714 - val_accuracy: 0.8701 - val_loss: 0.3039
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8888 - loss: 0.2681 - val_accuracy: 0.8701 - val_loss: 0.2945
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8852 - loss: 0.2601 - val_accuracy: 0.8766 - val_loss: 0.2870
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8989 - loss: 0.2324 - val_accuracy: 0.8831 - val_loss: 0.2799
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8976 - loss: 0.2443 - val_accuracy: 0.8961 - val_loss: 0.2691
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9069 - loss: 0.2109 - val_accuracy: 0.8961 - val_loss: 0.2603
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9174 - loss: 0.2063 - val_accuracy: 0.9091 - val_loss: 0.2535
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9172 - loss: 0.2121 - val_accuracy: 0.9091 - val_loss: 0.2430
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9245 - loss: 0.1761 - val_accuracy: 0.9091 - val_loss: 0.2358
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9302 - loss: 0.1861 - val_accuracy: 0.9221 - val_loss: 0.2267
# Epoch 20/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9475 - loss: 0.1639 - val_accuracy: 0.9221 - val_loss: 0.2186
# Epoch 21/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9391 - loss: 0.1670 - val_accuracy: 0.9286 - val_loss: 0.2127
# Epoch 22/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9434 - loss: 0.1627 - val_accuracy: 0.9221 - val_loss: 0.2028
# Epoch 23/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9215 - loss: 0.1862 - val_accuracy: 0.9221 - val_loss: 0.1978
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9375 - loss: 0.1535 - val_accuracy: 0.9221 - val_loss: 0.1944
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9348 - loss: 0.1581 - val_accuracy: 0.9221 - val_loss: 0.1851
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9431 - loss: 0.1498 - val_accuracy: 0.9286 - val_loss: 0.1801
# Epoch 27/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9666 - loss: 0.1282 - val_accuracy: 0.9351 - val_loss: 0.1787
# Epoch 28/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9565 - loss: 0.1418 - val_accuracy: 0.9351 - val_loss: 0.1723
# Epoch 29/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9695 - loss: 0.1195 - val_accuracy: 0.9416 - val_loss: 0.1648
# Epoch 30/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9491 - loss: 0.1222 - val_accuracy: 0.9416 - val_loss: 0.1608
# Epoch 31/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9558 - loss: 0.1321 - val_accuracy: 0.9545 - val_loss: 0.1561
# Epoch 32/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9563 - loss: 0.1287 - val_accuracy: 0.9481 - val_loss: 0.1582
# Epoch 33/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1192 - val_accuracy: 0.9481 - val_loss: 0.1487
# Epoch 34/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9697 - loss: 0.1030 - val_accuracy: 0.9610 - val_loss: 0.1417
# Epoch 35/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9680 - loss: 0.1141 - val_accuracy: 0.9481 - val_loss: 0.1380
# Epoch 36/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9608 - loss: 0.1120 - val_accuracy: 0.9416 - val_loss: 0.1372
# Epoch 37/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9729 - loss: 0.0878 - val_accuracy: 0.9481 - val_loss: 0.1332
# Epoch 38/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9701 - loss: 0.1004 - val_accuracy: 0.9610 - val_loss: 0.1373
# Epoch 39/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9648 - loss: 0.1094 - val_accuracy: 0.9675 - val_loss: 0.1201
# Epoch 40/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9686 - loss: 0.0949 - val_accuracy: 0.9740 - val_loss: 0.1181
# Epoch 41/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9833 - loss: 0.0852 - val_accuracy: 0.9740 - val_loss: 0.1157
# Epoch 42/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9766 - loss: 0.0853 - val_accuracy: 0.9740 - val_loss: 0.1146
# Epoch 43/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9815 - loss: 0.0848 - val_accuracy: 0.9740 - val_loss: 0.1091
# Epoch 44/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9682 - loss: 0.0910 - val_accuracy: 0.9740 - val_loss: 0.1042
# Epoch 45/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9749 - loss: 0.0792 - val_accuracy: 0.9740 - val_loss: 0.1036
# Epoch 46/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9748 - loss: 0.0823 - val_accuracy: 0.9740 - val_loss: 0.1033
# Epoch 47/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9707 - loss: 0.0914 - val_accuracy: 0.9740 - val_loss: 0.1007
# Epoch 48/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9754 - loss: 0.0750 - val_accuracy: 0.9740 - val_loss: 0.0992
# Epoch 49/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9857 - loss: 0.0725 - val_accuracy: 0.9805 - val_loss: 0.0941
# Epoch 50/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9656 - loss: 0.0809 - val_accuracy: 0.9740 - val_loss: 0.0979
# Epoch 51/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9745 - loss: 0.0661 - val_accuracy: 0.9805 - val_loss: 0.0995
# Epoch 52/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9718 - loss: 0.0779 - val_accuracy: 0.9805 - val_loss: 0.0994
# Epoch 53/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9844 - loss: 0.0631 - val_accuracy: 0.9805 - val_loss: 0.0947
# Epoch 54/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9903 - loss: 0.0611 - val_accuracy: 0.9805 - val_loss: 0.0977
# Epoch 55/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9885 - loss: 0.0542 - val_accuracy: 0.9805 - val_loss: 0.1018
# Epoch 56/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9767 - loss: 0.0717 - val_accuracy: 0.9805 - val_loss: 0.0921
# Epoch 57/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9846 - loss: 0.0596 - val_accuracy: 0.9805 - val_loss: 0.0884
# Epoch 58/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9816 - loss: 0.0569 - val_accuracy: 0.9805 - val_loss: 0.0851
# Epoch 59/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9862 - loss: 0.0597 - val_accuracy: 0.9805 - val_loss: 0.0877
# Epoch 60/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9872 - loss: 0.0566 - val_accuracy: 0.9805 - val_loss: 0.0884
# Epoch 61/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9894 - loss: 0.0468 - val_accuracy: 0.9805 - val_loss: 0.0795
# Epoch 62/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9871 - loss: 0.0463 - val_accuracy: 0.9805 - val_loss: 0.0774
# Epoch 63/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9858 - loss: 0.0456 - val_accuracy: 0.9805 - val_loss: 0.0815
# Epoch 64/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9861 - loss: 0.0441 - val_accuracy: 0.9805 - val_loss: 0.0811
# Epoch 65/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9914 - loss: 0.0358 - val_accuracy: 0.9805 - val_loss: 0.0818
# Epoch 66/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9807 - loss: 0.0606 - val_accuracy: 0.9805 - val_loss: 0.0841
# Epoch 67/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9831 - loss: 0.0428 - val_accuracy: 0.9805 - val_loss: 0.0745
# Epoch 68/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9774 - loss: 0.0718 - val_accuracy: 0.9805 - val_loss: 0.0761
# Epoch 69/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9885 - loss: 0.0439 - val_accuracy: 0.9805 - val_loss: 0.0791
# Epoch 70/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9813 - loss: 0.0548 - val_accuracy: 0.9805 - val_loss: 0.0756
# Epoch 71/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9948 - loss: 0.0317 - val_accuracy: 0.9805 - val_loss: 0.0788
# Epoch 72/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9933 - loss: 0.0376 - val_accuracy: 0.9805 - val_loss: 0.0722
# Epoch 73/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9878 - loss: 0.0392 - val_accuracy: 0.9805 - val_loss: 0.0657
# Epoch 74/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9961 - loss: 0.0347 - val_accuracy: 0.9805 - val_loss: 0.0714
# Epoch 75/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9877 - loss: 0.0388 - val_accuracy: 0.9675 - val_loss: 0.0758
# Epoch 76/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9921 - loss: 0.0361 - val_accuracy: 0.9805 - val_loss: 0.0707
# Epoch 77/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9836 - loss: 0.0401 - val_accuracy: 0.9805 - val_loss: 0.0726
# Epoch 78/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9896 - loss: 0.0323 - val_accuracy: 0.9870 - val_loss: 0.0675
# Epoch 79/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9900 - loss: 0.0334 - val_accuracy: 0.9870 - val_loss: 0.0676
# Epoch 80/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9932 - loss: 0.0347 - val_accuracy: 0.9870 - val_loss: 0.0659
# Epoch 81/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9934 - loss: 0.0247 - val_accuracy: 0.9805 - val_loss: 0.0776
# Epoch 82/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9929 - loss: 0.0282 - val_accuracy: 0.9870 - val_loss: 0.0662
# Epoch 83/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9870 - loss: 0.0430 - val_accuracy: 0.9935 - val_loss: 0.0580
# Epoch 84/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0313 - val_accuracy: 0.9935 - val_loss: 0.0582
# Epoch 85/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9931 - loss: 0.0323 - val_accuracy: 0.9870 - val_loss: 0.0581
# Epoch 86/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9956 - loss: 0.0310 - val_accuracy: 0.9870 - val_loss: 0.0602
# Epoch 87/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9922 - loss: 0.0286 - val_accuracy: 0.9870 - val_loss: 0.0621
# Epoch 88/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9863 - loss: 0.0319 - val_accuracy: 0.9935 - val_loss: 0.0526
# Epoch 89/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9964 - loss: 0.0264 - val_accuracy: 0.9935 - val_loss: 0.0548
# Epoch 90/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0448 - val_accuracy: 0.9935 - val_loss: 0.0499
# Epoch 91/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.0256 - val_accuracy: 0.9935 - val_loss: 0.0521
# Epoch 92/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9930 - loss: 0.0252 - val_accuracy: 0.9935 - val_loss: 0.0657
# Epoch 93/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9940 - loss: 0.0261 - val_accuracy: 0.9935 - val_loss: 0.0680
# Epoch 94/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9913 - loss: 0.0326 - val_accuracy: 0.9935 - val_loss: 0.0676
# Epoch 95/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9968 - loss: 0.0292 - val_accuracy: 0.9935 - val_loss: 0.0634
# Epoch 96/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9924 - loss: 0.0295 - val_accuracy: 0.9935 - val_loss: 0.0617
# Epoch 97/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9924 - loss: 0.0493 - val_accuracy: 0.9935 - val_loss: 0.0578
# Epoch 98/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0275 - val_accuracy: 0.9935 - val_loss: 0.0598
# Epoch 99/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9982 - loss: 0.0220 - val_accuracy: 0.9935 - val_loss: 0.0603
# Epoch 100/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9896 - loss: 0.0291 - val_accuracy: 0.9935 - val_loss: 0.0629

# %%
import matplotlib.pyplot as plt

# Loss Curves
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Training vs Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Train Loss", "Val Loss"])
plt.show()

# Accuracy Curves
plt.figure(figsize=(10,5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Training vs Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["Train Acc", "Val Acc"])
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Predict
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Evaluation Metrics
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        75
#            1       0.98      1.00      0.99        79
#
#     accuracy                           0.99       154
#    macro avg       0.99      0.99      0.99       154
# weighted avg       0.99      0.99      0.99       154

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, mean_squared_error, roc_auc_score

# Predictions
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred_prob)

print("Model Evaluation Metrics:")
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("MSE:", mse)
print("AUC Score:", auc)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Model Evaluation Metrics:
# Accuracy: 0.987012987012987
# Precision: 0.9753086419753086
# Recall: 1.0
# F1-score: 0.9875
# MSE: 0.012987012987012988
# AUC Score: 0.9969620253164558

# %%
from sklearn.metrics import classification_report

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        75
#            1       0.98      1.00      0.99        79
#
#     accuracy                           0.99       154
#    macro avg       0.99      0.99      0.99       154
# weighted avg       0.99      0.99      0.99       154

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Loss Curve
plt.figure(figsize=(10,5))
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Training vs Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Train Loss", "Validation Loss"])
plt.show()

# Accuracy Curve
plt.figure(figsize=(10,5))
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Training vs Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["Train Accuracy", "Validation Accuracy"])
plt.show()

# %%
from sklearn.metrics import roc_curve

fpr, tpr, threshold = roc_curve(y_test, y_pred_prob)

plt.figure(figsize=(7,5))
plt.plot(fpr, tpr)
plt.plot([0,1],[0,1],'--')
plt.title("ROC Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.show()
